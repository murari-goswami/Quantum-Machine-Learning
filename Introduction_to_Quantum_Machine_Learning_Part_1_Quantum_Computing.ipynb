# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadip1995/Quantum-Machine-Learning/blob/master/Introduction_to_Quantum_Machine_Learning_Part_1_Quantum_Computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# But First lets talk a little bit about Quantum Mechanics
#
#
# ##What is  quantum mechanics?
#
#
#
# ![alt text](https://camo.githubusercontent.com/8cd57dde64778850cb16b322809b2b07efbb04c3/687474703a2f2f7777772e696c6563747572656f6e6c696e652e636f6d2f646f776e6c6f61642f636861707465722e7468756d626e61696c2e613932363637313131393263383931652e333136663636333932653661373036372e6a7067)
#
#
#
#
#
# ###Quantum mechanics is the body of scientific laws that describe the motion and interaction of photons, electrons, and the other subatomic particles that make up the universe.
#
#
#
# ![alt text](https://camo.githubusercontent.)
#
#
#
# 1) In our universe, we are used to one truth.
#
# 2)  A coin, for example, can land on either heads or tails.
#
# 3) But if the coin followed the rules of quantum mechanics the coin would be flipping midair.
#
# 4) The coin would be both heads and tails simultaneously in the air.
#
# 5) The coin could be 70% heads and 30% tails for example. Simultaneously.
#
# 6) The coin would stay in midair until its observed.
#
#
# ###How do we even begin describe this kind of behavior? Mathematically!
#
# ![alt text](https://camo.githubusercontent.)
#
# 1) Particles like electrons seem to act like waves, and light-waves like particles.
#
# 2) Particles have a wavelength.
#
# 3) This was demonstrated during the double slit experiment.
#
#
# ![alt text](https://camo.githubusercontent.com/cf49c5f29576e1630a91913bbc45f636c662a5bc/687474703a2f2f7777772e626f74746f6d6c617965722e636f6d2f626f74746f6d2f7265616c6974792f696d616765732f6c69676874736c6974706f737369626c652e676966)
#
# A pair of parallel slits is placed in a partition between a beam of particles and a wall
# A detector is on the wall to see what happens and a strange pattern of stripes appear.
# This is called an interference pattern.
#
# ![alt text](https://camo.githubusercontent.com/1f8c7fa0cca917d9f09855a93b76b229b18f38b4/687474703a2f2f7777772e73616275726368696c6c2e636f6d2f706879736963732f696d616765735f77617665732f796f756e675f30352e6a7067)
#
#
# Like waves, the particles-waves that travel through one slit interfere with those that travel through the other slit.
# If the peak of the wave aligns with a trough, the particles cancel out and nothing shows up.
# If the peak aligns with another peak, the signal in the detector would be even brighter.
# This interference pattern still exists even if you only send one electron at a time.
#
#
# ###Schrodinger's equation helps describe this particle-wave duality.
#
#
# ![alt text](https://camo.githubusercontent.com/744778549d3e720ff8da059ae34777ff15c4c432/687474703a2f2f6879706572706879736963732e7068792d617374722e6773752e6564752f68626173652f7175616e74756d2f696d677175612f736368312e676966)
#
#
# ###The 3 features of quantum mechanics that quantum algorithms exploit.
#
#
# ![alt text](https://camo.githubusercontent.com/13218ebfde066002619d4a2723217b49b5428c35/687474703a2f2f7777772e7369727465712e6f72672f77702d636f6e74656e742f75706c6f6164732f323031372f30352f5375706572706f736974696f6e2d332e706e67)
#
#
# ###Superposition
#
# The midair coin being heads and tails at the same time.
#
#
# ![alt text](https://camo.githubusercontent.com/868cf4027a8d1c8d24eaa257849cd236b986c7a2/687474703a2f2f7777772e67656f72676c696e642e646b2f66696c65732f696e746572666572656e63655f696e5f7472616e73706f72745f7468726f7567685f73696e676c655f6d6f6c6563756c65732f30312d646f75626c65736c69742e706e67)
#
# ###Interference
#
# Probability waves overlapping and canceling each other out.
#
# ![alt text](https://camo.githubusercontent.com/f50c0447dd259847bb241aeeef6c90da8dea7013/687474703a2f2f696d6167652e77696b69666f756e6472792e636f6d2f696d6167652f312f364f44626775736250425957687371595a44496a504131303834372f475732383148313637)
#
#
# ###Entanglement
#
# If we tied a bunch of coins together, each would effect the probabilities of the other.
#
#
# ##Introducing  Quantum computing
#
#
# Quantum Computing was started in the early 1980s when Richard Feynman and Yuri Manin expressed the idea that a quantum computer had the potential to simulate things that a classical computer could not.
#
# ![alt text](https://i1.wp.com/www.brainpickings.org/wp-content/uploads/2012/09/richardfeynman1.jpg)
#
# ###Basic idea:
#
# Quantum computers uses quantum bits or qubits. More on that later. Qubits are fundamental to Quantum computing
# .
# A classical computer can compute 2 x n states, whereas In general, a quantum computer with  n qubits can be in any superposition of up to $2^n$ different states. So, even if enough data isn't available, a quantum computer can find unseen possibilities buried deep within.
#
# It can be used for finding optimal solutions where there is simply no possibility of finding any because of a lack of data. It can generate patterns that a classical computer could never process with the same number of bits. So, you can see the endless possibilities here.

# %% [markdown]
# ##Qubits:
#
#
# ![alt text](https://www.autodesk.com/products/eagle/blog/wp-content/uploads/2017/05/qubit.png)
#
# The Qubit Ends up in a Ground and excited state of complex magnitude
#
# 1) Today's computers, like a Turing machine, work by manipulating bits that exist in one of two states: a 0 or a 1.
#
#
# 2) Quantum computers aren't limited to two states; they encode information as quantum bits, or qubits, which can exist in superposition. It exists in ground and excited state with a complex amplitude.(see in the first picture)
#
# 3)  Qubits represent atoms, ions, photons or electrons and their respective control devices that are working together to act as computer memory and a processor.
#
# 4) Because a quantum computer can contain these multiple states simultaneously, it has the potential to be millions of times more powerful than today's most powerful supercomputers.
# This superposition of qubits is what gives quantum computers their inherent parallelism.
# In quantum mechanics, the general quantum state of a qubit can be represented by a linear superposition of its two vectors. As you can see in the first picture.
#
# |1> and |0> are the Dirac notations of Qubits
#
# ### Tangle Lake,’ Intel’s 49-Qubit Processor(still in testing phase) below
#
# ![alt text](https://newsroom.intel.com/wp-content/uploads/sites/11/2018/05/49-qubit-processor-tangle-lake-infographic-sm-690x460.jpg)
#
#
# ![alt text](https://camo.githubusercontent.com/6715d46c500410924b7051e3c5af4a222c957821/687474703a2f2f7265766973746170657371756973612e6661706573702e62722f77702d636f6e74656e742f75706c6f6164732f323031322f30362f3035375f446973636f726469615175616e746963615f3139332d312e6a7067)
#
#
# 1) qubits unlike classical computers can be in a superposition of both 0 and 1
# a complex system of qubits can be in many superpositions at once, example 5 qubits can be in a superposition of 32 states (2^n).
#
# 2)  entangled qubits are correlated with one another, information on one qubit will reveal information about the other unknown qubit
# Together both properties of superposition and entanglement will enable qubits to compute huge amounts of data simultaneously and solve complex problems such as optimization which classical computers would take millions of years to calculate.

# %% [markdown]
# ##Superposition and Entanglement in Qubits
#
# ##Quantum entanglement:
#
#
# Quantum entanglement is a physical phenomenon that occurs when pairs or groups of particles are generated, interact, or share spatial proximity in ways such that the quantum state of each particle cannot be described independently of the state of the others, even when the particles are separated by a large distance.
#
# ![alt text](http://www.astronomy.com/-/media/Images/News%20and%20Observing/News/2018/08/quantumentanglement.jpg?mw=600)
#
# ###In Qubits: .
#
#
# Quantum entanglement is a nonlocal(in theoretical physics non local means measurements that are made in microscopic states, but contradicts in classical states) property of two or more qubits that allows a set of qubits to express higher correlation than is possible in classical systems.
#
# ![alt text](https://slideplayer.com/slide/4950778/16/images/5/Quantum+Entanglement+%2B+and.+%28dead%2C+live%29+%28live%2C+dead%29+if+this+were+the+state+of+two+macroscopic+objects..jpg)
#
#
# Applications of quantum entanglement are: quantum computation and communication, such as quantum teleportation etc.

# %% [markdown]
# ##Quantum superposition:
#
# superposition is a fundamental principle of quantum mechanics. It states that, much like waves in classical physics, any two (or more) quantum states can be added together ("superposed") and the result will be another valid quantum state; and conversely, that every quantum state can be represented as a sum of two or more other distinct states.
#
#
#
#
#
# ![alt text](https://slideplayer.com/slide/4950778/16/images/3/Two+key+properties+of+quantum+systems.jpg)
#
# The quantum logical qubit state, as used in quantum information processing, is a quantum superposition of the states |0> and |1> .(picture above) Here |0> is the Dirac notation for the quantum state that will always give the result 0 when converted to classical logic by a measurement. Likewise |1>  is the state that will always convert to 1. .

# %% [markdown]
# ##Quantum Processing Unit
#
# Quantum processing unit (QPU) introduction.
#
#
# ![alt text](https://camo.githubusercontent.com/1615cc2cdc782412ff06f5febdc423cc05ea0356/68747470733a2f2f63646e2e746563687465726d732e636f6d2f696d672f6c672f636d6f735f3232322e6a7067)
# .
# ###Lets take a look at a few points.
#
# 1) The way that we encode and access information in digital computers is by adjusting and monitoring voltages that are present on tiny transistor switches inside integrated circuits. (CMOS). So we use the idea of an electrical voltage to 'encode' bits of information in a physical device.Picture  Above
#
#
# 2) Quantum computers have similarities to and differences from this CMOS transistor idea.
#
# 3) The picture below shows a schematic illustration of what is known as a superconducting qubit (also called a SQUID), which is the basic building block of a quantum computer (a quantum 'transistor', if you like).
#
# ![alt text](https://camo.githubusercontent.com/e9a9177fc4c28902e021b697fa6ebad4acd5c86f/68747470733a2f2f7777772e64776176657379732e636f6d2f73697465732f64656661756c742f66696c65732f7475742d68617264776172652d71756269742d736368656d617469632e6a7067)
#
#
# The name SQUID comes from the phrase Superconducting Quantum Interference Device. Interference refers to the electron waves inside.
#
#
#
#
# The reason that quantum effects such as electron waves are supported in such a structure - allowing it to behave as a qubit - is due to the properties of the material from which it is made. Niobium. When this is cooled down, it starts behaving like a superconductor and exhibits quantum mechanical effects
# .

# %% [markdown]
# ![alt text](https://camo.githubusercontent.com/a02c9086ab5a617718b5573656ec5d151011cbc6/687474703a2f2f6879706572706879736963732e7068792d617374722e6773752e6564752f68626173652f536f6c6964732f696d67736f6c2f7371756964652e706e67)
#
#
# A regular transistor allows you to encode 2 different states (using voltages).
#
# The superconducting qubit structure instead encodes 2 states as tiny magnetic fields, which either point up or down. - We call these states +1 and -1, and they correspond to the two states that the qubit can 'choose' between.
#
# Using the quantum mechanics that is accessible with these structures, we can control this object so that we can put the qubit into a superposition of these two states as described earlier.
# So by adjusting a control knob on the quantum computer, you can put all the qubits into a superposition state where it hasn't yet decided which of those +1, -1 states to be.
#
#
# ![alt text](https://camo.githubusercontent.com/d4bc25119dd5026bf34145ecc342c59c2c7d0538/68747470733a2f2f7777772e64776176657379732e636f6d2f73697465732f64656661756c742f66696c65732f7475742d68617264776172652d71756269742d6c6f6f70732e6a7067)
#
#
# 1) This is a Schematic of a superconducting qubit, the basic building block of the D-Wave quantum computer.
#
# 2) The arrows indicate the magnetic spin states which encode the bits of information as +1 and -1 values.
#
# 3) Unlike regular bits of information, these states can be put into quantum mechanical superposition.
#
# 4) In order to go from a single qubit to a multi-qubit processor, the qubits must be connected together such that they can exchange information.
#
# 5) This is achieved through the use of elements known as couplers.
#
# 6) The couplers are also made from superconducting loops.
#
# 7) By putting many such elements (qubits and couplers) together, we can start to build up a fabric of quantum devices that are programmable.
#
# 8) The image shows a schematic of 8 connected qubits.
#
# 9) The loop shown in the previous diagram has now been stretched out to form one of the long gold rectangles.
#
# 10) At the points where the rectangles cross, the couplers have been shown schematically as blue dots.
#
# 11) This is a schematic illustration of 8 qubit loops (gold).
#
# 12) The blue dots are the locations of the 16 coupling elements that allow the qubits to exchange information.
#
# 13) Mathematically, these elements couple together variables in a problem that you wish the computer to solve.
#
#
# ![alt text](https://camo.githubusercontent.com/f6bb1c4b61ca687a3f37b55a72fb670c33c8bfc8/68747470733a2f2f7777772e6c6561726e65722e6f72672f636f75727365732f706879736963732f76697375616c2f696d675f6c72672f73717569642e6a7067)
#
#
# Additionally it uses switches that form circuitry that routes magnetic pulse data and stores it in memory
# Also, there are readout devices attached to each qubit
# The QPU has no large areas of memory (cache), rather each qubit has a tiny piece of memory of its own.
# In fact, the QPU is architected more like a biological brain than the common 'Von Neumann' architecture of a conventional silicon processor.
# One can think of the qubits as being like neurons, and the couplers as being like synapses that control the flow of information between those neurons.
#
#
#
# ##What are the Applications of Quantum Computing?
#
# ###For a subset of classical problems, quantum computing makes a dramatic difference.
#
# ![alt text](https://camo.githubusercontent.)
#
#
#
#
# 1) Aerospace engineering: Optimal mesh partitioning for finite elements
#
# 2) Biology: Phylogeny reconstruction
#
# 3) Chemical engineering: Heat exchanger network synthesis
#
# 4) Chemistry: Protein folding
#
# 5) Civil engineering: Equilibrium of urban traffic flow.
#
# 6) Economics: Computation of arbitrage in financial markets with friction.
#
# 7) Electrical engineering: VLSI layout.
#
# 8) Environmental engineering: Optimal placement of contaminant sensors.
#
# 9) Financial engineering: Minimum risk portfolio of given return.
#
# 10) Game theory: Nash equilibrium that maximizes social welfare.
#
# 11) Mechanical engineering: Structure of turbulence in sheared flows.
#
# 12) Medicine: Reconstructing 3d shape from biplane angiocardiogram.
#
# 13) Operations research: Traveling salesperson problem.
#
# 14) Physics: Partition function of 3d Ising model.
#
# 15) Politics: Shapley-Shubik voting power.
#
# 16) Recreation: Versions of Sudoko, Checkers, Minesweeper, Tetris.
#
# 17) Statistics: Optimal experimental design.
